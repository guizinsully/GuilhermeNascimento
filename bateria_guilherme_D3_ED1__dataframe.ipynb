# %% [markdown]
# <a href="https://colab.research.google.com/github/guizinsully/ProjetodeDataFrame/blob/main/bateria_guilherme_D3_ED1__dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROVA A1 - 05/06
# #Guilherme Silva do Nascimento - RGM: 1435882999
# #Estrtura de Dados I - D3 (Mat)
# Aqui eu estou importando a biblioteca, criando as listas, o dicionário e o DataFrame.

# %%
import pandas as pd
# importamos a biblioteca para poder utilizar dos seus métodos
# Vamos fazer um dict sobre Crashs, Rides e Efects (Ataque, Condução e Efeito)
modelos = ["Crash Zildjian KCustom Dry Series", "Ride Bronz Cymbals Roots", "Splash Turkish moderate HH14", "HitHat Meinl Class Custom Dark", "Zeus Stack Clap Zs13 Trio", "22 Waldman Ottoman Ride", "Crash BFC Dry Dark Holed"]
polegadas = [18, 21, 6, 14, "9/11/13", 22, 20]
tipagem = ["B8", "B20", "Latão", "B8", "B10", "B20", "Bronze"]
espessura = ["Fino-Médio", "Fino-Médio", "Fino", "Fino-Médio", "Fino", "Grosso", "Médio"]
preco = [2.763, 3.569, 1.079, 4.876, 1.113, 1.750, 1.587]
# criando o dicionário
dados_modelos = {
    'Pratos': modelos,
    'Polegadas': polegadas,
    'Tipagem': tipagem,
    'Espessura': espessura,
    'Preço': preco
}
# Todas as informações foram tiradas de diversos sites de compras de materiais músicais
modelos_df = pd.DataFrame(dados_modelos)
display(modelos_df)
# Out:
#                               Pratos Polegadas Tipagem   Espessura  Preço
# 0  Crash Zildjian KCustom Dry Series        18      B8  Fino-Médio  2.763
# 1           Ride Bronz Cymbals Roots        21     B20  Fino-Médio  3.569
# 2       Splash Turkish moderate HH14         6   Latão        Fino  1.079
# 3     HitHat Meinl Class Custom Dark        14      B8  Fino-Médio  4.876
# 4          Zeus Stack Clap Zs13 Trio   9/11/13     B10        Fino  1.113
# 5            22 Waldman Ottoman Ride        22     B20      Grosso  1.750
# 6           Crash BFC Dry Dark Holed        20  Bronze       Médio  1.587

# %% [markdown]
# # Questão 1 - Apresente em tela (output) toda a base de dados.
# #Espera-se que você exiba todo o conteúdo da base de dados na saída.

# %%
print ("Questão 1 - Apresentar o output:")
display(modelos_df)
# a função display é usada para deixar com uma estética mais bonita e organizada, mas também pode ser somente um print que roda normalmente
# Out:
# Questão 1 - Apresentar o output:
#                               Pratos Polegadas Tipagem   Espessura  Preço
# 0  Crash Zildjian KCustom Dry Series        18      B8  Fino-Médio  2.763
# 1           Ride Bronz Cymbals Roots        21     B20  Fino-Médio  3.569
# 2       Splash Turkish moderate HH14         6   Latão        Fino  1.079
# 3     HitHat Meinl Class Custom Dark        14      B8  Fino-Médio  4.876
# 4          Zeus Stack Clap Zs13 Trio   9/11/13     B10        Fino  1.113
# 5            22 Waldman Ottoman Ride        22     B20      Grosso  1.750
# 6           Crash BFC Dry Dark Holed        20  Bronze       Médio  1.587

# %% [markdown]
# # Questão 2 - Apresente o tamanho do seu dataframe (quantas colunas x linhas).
# #Você deve retornar o número de colunas e o número de linhas do dataframe.

# %%
print("Questão 2 - Tamanho do dataframe (linhas, colunas):")
print(modelos_df.shape)
# O método "shape" é usada para contar quantas linhas e quantas colunas existem no código, utilizando logo após o seu DataFrame
# Out:
# Questão 2 - Tamanho do dataframe (linhas, colunas):
# (7, 5)

# %% [markdown]
# # Questão 3 - Acesse a linha (x) e apresente em tela todas as características do item.
# #Você deve acessar a linha específica (x) e exibir todas as suas características ou colunas.

# %%
print ("Questão 3 - Acessar a linha(x) e apresentar:")
display(modelos_df.loc[[3]])
# loc é um método de localização e o index para localizar qual objeto você deseja
# Out:
# Questão 3 - Acessar a linha(x) e apresentar:
#                            Pratos Polegadas Tipagem   Espessura  Preço
# 3  HitHat Meinl Class Custom Dark        14      B8  Fino-Médio  4.876

# %% [markdown]
# # Questão 4 - Verifique se o dataframe está vazio.
# #Você deve verificar se o dataframe está vazio e fornecer o resultado dessa verificação

# %%
print("Questão 4 - Verificação se o dataframe está vazio:")
def esta_vazio(df):
  if modelos_df.empty:
   return "O dataframe está vazio."
  else:
    return f"O dataframe não está vazio."
print(f"Está vazio ou não...?\n\n{esta_vazio(df=modelos_df)}")
# Out:
# Questão 4 - Verificação se o dataframe está vazio:
# Está vazio ou não...?
#
# O dataframe não está vazio.

# %% [markdown]
# # Questão 5 - Apresente em tela os 5 primeiros registros da base de dados.
# #Você deve exibir os 5 primeiros registros (linhas) da base de dados.

# %%
print("5) Primeiros 5 registros:")
# O metodo Heada lê as primeiras linhas em ordem do seu código, após ele se abrem parênteses e colocamos uma "função" de parada, como se pede:
display(modelos_df.head(5))
# Out:
# 5) Primeiros 5 registros:
#                               Pratos Polegadas Tipagem   Espessura  Preço
# 0  Crash Zildjian KCustom Dry Series        18      B8  Fino-Médio  2.763
# 1           Ride Bronz Cymbals Roots        21     B20  Fino-Médio  3.569
# 2       Splash Turkish moderate HH14         6   Latão        Fino  1.079
# 3     HitHat Meinl Class Custom Dark        14      B8  Fino-Médio  4.876
# 4          Zeus Stack Clap Zs13 Trio   9/11/13     B10        Fino  1.113

# %% [markdown]
# # Questão 6 - Exclua um item (linha) de sua base de dados.
# #Você deve remover um item (linha) específico da base de dados

# %%
# Esse metodo ele realiza a exclusão de uma linha, mas eu não consegui fazer a tabela aparecer aqui
modelos_df = modelos_df.drop(5)

# %% [markdown]
# # Questão 7 - Adicione um item (linha) na sua base de dados.
# #Você deve adicionar um novo item (linha) à base de dados.

# %%
# Realize a adição de uma linha com um novo Item através do metodo len, e cada item do objeto em ordem correta.
novo_item = ["Crash BFC Dry Dark Holed", 22, "B20", "Fino-Médio", 1.587]
modelos_df.loc[len(modelos_df)] = novo_item
display (modelos_df)
# Out:
#                               Pratos Polegadas Tipagem   Espessura  Preço
# 0  Crash Zildjian KCustom Dry Series        18      B8  Fino-Médio  2.763
# 1           Ride Bronz Cymbals Roots        21     B20  Fino-Médio  3.569
# 2       Splash Turkish moderate HH14         6   Latão        Fino  1.079
# 3     HitHat Meinl Class Custom Dark        14      B8  Fino-Médio  4.876
# 4          Zeus Stack Clap Zs13 Trio   9/11/13     B10        Fino  1.113
# 6           Crash BFC Dry Dark Holed        22     B20  Fino-Médio  1.587

# %% [markdown]
# # Questão 8 - Transponha a coluna para a linha em sua base de dados.
# #Você deve realizar a transposição de uma coluna para uma linha na base de dados.

# %%
dataframe_transposed = modelos_df.T
#O método transposed para colocar a linhas no mesmo "sentido" das colunas
print("8) Transposição da coluna para a linha:")
display(dataframe_transposed)
modelos_df = modelos_df.transpose()
# Out:
# 8) Transposição da coluna para a linha:
#                                            0                         1  \
# Pratos     Crash Zildjian KCustom Dry Series  Ride Bronz Cymbals Roots
# Polegadas                                 18                        21
# Tipagem                                   B8                       B20
# Espessura                         Fino-Médio                Fino-Médio
# Preço                                  2.763                     3.569
#
#                                       2                               3  \
# Pratos     Splash Turkish moderate HH14  HitHat Meinl Class Custom Dark
# Polegadas                             6                              14
# Tipagem                           Latão                              B8
# Espessura                          Fino                      Fino-Médio
# Preço                             1.079                           4.876
#
#                                    4                         6
# ...

# %% [markdown]
# # Questão 9 - Apresente em tela somente a 1ª e a 2ª coluna (rótulo) da base de dados.
# #Você deve exibir apenas as colunas 1 e 2 (rótulo) da base de dados.

# %%
print("QUestão 9 - Mostre a 1ª e 2ª coluna:")
#aqui usamos o display para melhor estética, dps colocamos o meu Dataframe e usamos a função iloc para pegar somente a coluna desejada
display(modelos_df.iloc[:, :2]) #ou
display(modelos_df.iloc[:, 0:2])
# Out:
# QUestão 9 - Mostre a 1ª e 2ª coluna:
#                                            0                         1
# Pratos     Crash Zildjian KCustom Dry Series  Ride Bronz Cymbals Roots
# Polegadas                                 18                        21
# Tipagem                                   B8                       B20
# Espessura                         Fino-Médio                Fino-Médio
# Preço                                  2.763                     3.569
#                                            0                         1
# Pratos     Crash Zildjian KCustom Dry Series  Ride Bronz Cymbals Roots
# Polegadas                                 18                        21
# Tipagem                                   B8                       B20
# Espessura                         Fino-Médio                Fino-Médio
# Preço                                  2.763                     3.569

# %% [markdown]
# # Questão 10 - Informe como foi desenvolvido o Projeto.
# Você deve fornecer uma breve descrição de como o projeto foi desenvolvido, quais técnicas e
# ferramentas foram utilizadas, e quais foram os principais desafios encontrados durante o
# desenvolvimento.

# %%
#Esse projeto foi desenvolvido pelo aluno da UDF, Guilherme Silva do Nascimento na aula de Estrtura de dados I da D3 (Mat), RGM: 1435882999
#Bom... o desenvolvimento desse projeto foi muito desafiador, pois até eu começar esse projeto eu não tinha feito algo tão grande e tão complexo, então partindo para o desenvolvimento.
#Eu pensei sobre esse assunto pois sou muito inserido nesse meio desde a minha infância, sou baterista tem 11 anos, e conheço esse mundo muito mais do que conheço qualquer outra coisa, então para mim
#foi um pouco óbvio o assunto que eu deveria abordar, por todos esses motivos, mas partindo para a ação, eu iniciei fazendo minha lista meu dicionário e importando minha biblioteca, e o que isso significa?
#Primeiramente nós carregamos a biblioteca (import pnadas as pd) para podermos usar todas as funções que ela disponibiliza, descritas nas questões logo a baixo, em seguida criamos as listas com os itens da Lista defnidos com a minha preferência,
#no caso eu escolhi um assunto de dominio, logo após foi feito um dicionário com esses mesmo itens, e após um Quadro de Dados para organização, a parte da pesquisa foi
#a mais fácil, pois como eu já tinhha todos esses conceitos de cabeça eu somente fiz uma breve pesquisa para saber o valor atual de cada item, eu utilizei tecnicas de outros notebooks que criamos juntos dentro
#da sala de aula e outros eu mesmo aprendi com alguns videos no YT, como no canal do "Programação Dinâmica" que até me explicou alguns conceitos que eu não sabia, e também a ajuda da IA do próprio colab em se eu não me engano em duas questões
#onde eu não tinha ideia de para onde ir, mas tudo de forma dinâmica e com muita aprendizagem, e tentando utilizar e explorar o máximo da minha própria cabeça, lembrando que eu utilizei o colab como principal e única IDE.
#OBS: Todos os meus comentários são ridiculamente constrangedores pois ainda não peguei bem o jeito de se comentar um código.
